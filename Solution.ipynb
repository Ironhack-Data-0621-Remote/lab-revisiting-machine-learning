# %%
import pandas as pd
import warnings

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('learningSet.csv')
# Out:
# C:\Users\Karo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081                    3712      0
# 1     9401     BOA      1    CA  91326                    5202      0
# 2     9001     AMH      1    NC  27017                       0      0
# 3     8701     BRY      0    CA  95953                    2801      0
# 4     8601              0    FL  33176                    2001      0
#
#   RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0           ...      0.0        0      L      4      E        X         X
# 1           ...      0.0        0      L      2      G        X         X
# 2           ...      0.0        1      L      4      E        X         X
# 3           ...      0.0        1      L      4      E        X         X
# 4        X  ...      0.0        1      L      2      F        X         X
#
#   MDMAUD_A CLUSTER2 GEOCODE2
# 0        X     39.0        C
# 1        X      1.0        A
# ...

# %%
list(data.columns)
# Out:
# ['ODATEDW',
#  'OSOURCE',
#  'TCODE',
#  'STATE',
#  'ZIP',
#  'MAILCODE',
#  'PVASTATE',
#  'DOB',
#  'NOEXCH',
#  'RECINHSE',
#  'RECP3',
#  'RECPGVG',
#  'RECSWEEP',
#  'MDMAUD',
#  'DOMAIN',
#  'CLUSTER',
#  'AGE',
#  'AGEFLAG',
#  'HOMEOWNR',
#  'CHILD03',
#  'CHILD07',
#  'CHILD12',
#  'CHILD18',
#  'NUMCHLD',
#  'INCOME',
#  'GENDER',
#  'WEALTH1',
#  'HIT',
#  'MBCRAFT',
#  'MBGARDEN',
#  'MBBOOKS',
#  'MBCOLECT',
#  'MAGFAML',
#  'MAGFEM',
#  'MAGMALE',
#  'PUBGARDN',
#  'PUBCULIN',
#  'PUBHLTH',
#  'PUBDOITY',
#  'PUBNEWFN',
#  'PUBPHOTO',
#  'PUBOPP',
#  'DATASRCE',
#  'MALEMILI',
#  'MALEVET',
#  'VIETVETS',
#  'WWIIVETS',
#  'LOCALGOV',
#  'STATEGOV',
#  'FEDGOV',
#  'SOLP3',
#  'SOLIH',
#  'MAJOR',
#  'WEALTH2',
#  'GEOCODE',
#  'COLLECT1',
#  'VETERANS',
#  'BIBLE',
#  'CATLG',
#  'HOMEE',
#  'PETS',
#  'CDPLAY',
#  'STEREO',
#  'PCOWNERS',
#  'PHOTO',
#  'CRAFTS',
#  'FISHER',
#  'GARDENIN',
#  'BOATS',
#  'WALKER',
#  'KIDSTUFF',
#  'CARDS',
#  'PLATES',
# ...

# %%
data[['TARGET_B','TARGET_D']]
# Out:
#        TARGET_B  TARGET_D
# 0             0       0.0
# 1             0       0.0
# 2             0       0.0
# 3             0       0.0
# 4             0       0.0
# ...         ...       ...
# 95407         0       0.0
# 95408         0       0.0
# 95409         0       0.0
# 95410         1      18.0
# 95411         0       0.0
#
# [95412 rows x 2 columns]

# %%
#nulls= (data.isna().sum().sort_values(ascending = False)/len(data)*100)
#nulls
nulls = pd.DataFrame(data.isna().sum().sort_values(ascending = False)/len(data)*100, columns=['percentage'])
nulls
# Out:
#          percentage
# RAMNT_5   99.990567
# RDATE_5   99.990567
# RAMNT_3   99.746363
# RDATE_3   99.746363
# RAMNT_4   99.705488
# ...             ...
# EIC13      0.000000
# EIC14      0.000000
# EIC15      0.000000
# EIC16      0.000000
# ODATEDW    0.000000
#
# [481 rows x 1 columns]

# %%
drop_col= list(nulls[nulls['percentage'] > 10].index)

# %%
len(drop_col)
# Out:
# 81

# %%
data1 = data.drop(columns=drop_col, axis=1)
data1.head()
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R MDMAUD_F  \
# ...

# %%
data1 = data1.drop(['ZIP', 'OSOURCE'], axis=1)
data1.head()
# Out:
#    ODATEDW  TCODE STATE MAILCODE PVASTATE   DOB NOEXCH RECINHSE RECP3 RECPGVG  \
# 0     8901      0    IL                    3712      0
# 1     9401      1    CA                    5202      0
# 2     9001      1    NC                       0      0
# 3     8701      0    CA                    2801      0
# 4     8601      0    FL                    2001      0        X     X
#
#    ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R MDMAUD_F MDMAUD_A  \
# 0  ...      0.0        0      L      4      E        X        X        X
# 1  ...      0.0        0      L      2      G        X        X        X
# 2  ...      0.0        1      L      4      E        X        X        X
# 3  ...      0.0        1      L      4      E        X        X        X
# 4  ...      0.0        1      L      2      F        X        X        X
#
#   CLUSTER2 GEOCODE2
# 0     39.0        C
# 1      1.0        A
# 2     60.0        C
# 3     41.0        C
# 4     26.0        A
#
# [5 rows x 398 columns]

# %%
(data1.isna().sum().sort_values(ascending = False)/len(data)*100)
# Out:
# ADATE_12    9.352073
# ADATE_7     9.300717
# ADATE_6     3.728043
# ADATE_8     3.679831
# ADATE_4     2.296357
#               ...
# OEDC3       0.000000
# OEDC4       0.000000
# OEDC5       0.000000
# OEDC6       0.000000
# ODATEDW     0.000000
# Length: 398, dtype: float64

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num = data1.select_dtypes(include=numerics)
num.head()
# Out:
#    ODATEDW  TCODE   DOB  HIT  MALEMILI  MALEVET  VIETVETS  WWIIVETS  LOCALGOV  \
# 0     8901      0  3712    0         0       39        34        18        10
# 1     9401      1  5202   16         0       15        55        11         6
# 2     9001      1     0    2         0       20        29        33         6
# 3     8701      0  2801    2         0       23        14        31         3
# 4     8601      0  2001   60         1       28         9        53        26
#
#    STATEGOV  ...  LASTGIFT  LASTDATE  FISTDATE    AVGGIFT  CONTROLN  TARGET_B  \
# 0         2  ...      10.0      9512      8911   7.741935     95515         0
# 1         2  ...      25.0      9512      9310  15.666667    148535         0
# 2         8  ...       5.0      9512      9001   7.481481     15078         0
# 3         0  ...      10.0      9512      8702   6.812500    172556         0
# 4         3  ...      15.0      9601      7903   6.864865      7112         0
#
# ...

# %%
cat=data1.select_dtypes(exclude=numerics)
cat.head()
# Out:
#   STATE MAILCODE PVASTATE NOEXCH RECINHSE RECP3 RECPGVG RECSWEEP MDMAUD  \
# 0    IL                        0                                   XXXX
# 1    CA                        0                                   XXXX
# 2    NC                        0                                   XXXX
# 3    CA                        0                                   XXXX
# 4    FL                        0        X     X                    XXXX
#
#   DOMAIN  ... RFA_21 RFA_22 RFA_23 RFA_24 RFA_2R RFA_2A MDMAUD_R MDMAUD_F  \
# 0     T2  ...    S4E    S4E    S4E    S4E      L      E        X        X
# 1     S1  ...    N1E    N1E           F1E      L      G        X        X
# 2     R2  ...           S4D    S4D    S3D      L      E        X        X
# 3     R2  ...    A1D    A1D                    L      E        X        X
# 4     S2  ...    A3D    I4E    A3D    A3D      L      F        X        X
#
#   MDMAUD_A GEOCODE2
# 0        X        C
# 1        X        A
# 2        X        C
# ...

# %%
print(cat['GENDER'].value_counts())
cat['GENDER'] = cat['GENDER'].fillna('F')
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
def clean_gender(x):
    if str(x).startswith('M'):
        return 'M'
    elif str(x).startswith('F'):
        return 'F'
    else:
        return 'O'

cat['GENDER'] = cat['GENDER'].apply(clean_gender)

cat['GENDER'].value_counts()
# Out:
# F    51277
# M    39094
# O     5041
# Name: GENDER, dtype: int64
